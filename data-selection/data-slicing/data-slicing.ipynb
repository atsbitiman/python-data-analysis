# %%
import pandas as pd

customer_data = pd.read_csv("customers_data.csv")
customer_data
# Out:
#     customerNumber        name              phone  \
# 0              103     Carine          40.32.2555
# 1              112        Jean         7025551838
# 2              114       Peter       03 9520 4555
# 3              119     Janine          40.67.8555
# 4              121      Jonas          07-98 9555
# 5              124       Susan         4155551450
# 6              125    Zbyszek       (26) 642-7555
# 7              128      Roland  +49 69 66 90 2555
# 8              129       Julie         6505555787
# 9              131        Kwai         2125557818
# 10             141      Diego      (91) 555 94 44
# 11             144  Christina        0921-12 3555
# 12             145      Jytte          31 12 3555
# 13             146       Mary          78.32.5555
# 14             148        Eric       +65 221 7555
# 15             151        Jeff         2125557413
# 16             157      Kelvin         2155551555
# 17             161        Juri         6505556809
# ...

# %%
customer_data.loc[1:3]
# Out:
#    customerNumber     name         phone                  addressline1  \
# 1             112     Jean    7025551838               8489 Strong St.
# 2             114    Peter  03 9520 4555             636 St Kilda Road
# 3             119  Janine     40.67.8555  67, rue des Cinquante Otages
#
#         city     state postalCode    country  creditLimit
# 1  Las Vegas        NV      83030        USA      71800.0
# 2  Melbourne  Victoria       3004  Australia     117300.0
# 3     Nantes       NaN      44000     France     118200.0

# %%
customer_data.loc[1:3,"phone":"state"]
# Out:
#           phone                  addressline1       city     state
# 1    7025551838               8489 Strong St.  Las Vegas        NV
# 2  03 9520 4555             636 St Kilda Road  Melbourne  Victoria
# 3    40.67.8555  67, rue des Cinquante Otages     Nantes       NaN

# %%
customer_data.loc[:,"city":"creditLimit"]
# Out:
#              city     state postalCode    country  creditLimit
# 0          Nantes        CA      44000     France      21000.0
# 1       Las Vegas        NV      83030        USA      71800.0
# 2       Melbourne  Victoria       3004  Australia     117300.0
# 3          Nantes       NaN      44000     France     118200.0
# 4         Stavern       NaN       4110     Norway      81700.0
# 5      San Rafael        CA      97562        USA     210500.0
# 6        Warszawa       NaN     01-012     Poland          0.0
# 7       Frankfurt       NaN      60528    Germany      59700.0
# 8   San Francisco        CA      94217        USA      64600.0
# 9             NYC        NY      10022        USA     114900.0
# 10         Madrid       NaN      28034      Spain     227600.0
# 11          Luleå       NaN   S-958 22     Sweden      53100.0
# 12      Kobenhavn       NaN       1734    Denmark      83400.0
# 13           Lyon       NaN      69004     France     123900.0
# ...

# %% [markdown]
# ## **MINI EXERCISE**

# %%
import pandas as pd

film = pd.read_csv("imdb_top_1000.csv")
film
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
film.head(5)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
list_film = film.loc[250:350][["Series_Title","Released_Year","Runtime","Genre","IMDB_Rating"]]
list_film
# Out:
#                Series_Title Released_Year  Runtime                      Genre  \
# 250         The Truman Show          1998  103 min              Comedy, Drama
# 251  Crna macka, beli macor          1998  127 min     Comedy, Crime, Romance
# 252        The Big Lebowski          1998  117 min       Comedy, Crime, Sport
# 253        Fa yeung nin wah          2000   98 min             Drama, Romance
# 254           Trainspotting          1996   93 min                      Drama
# ..                      ...           ...      ...                        ...
# 346       The King's Speech          2010  118 min  Biography, Drama, History
# 347                The Help          2011  146 min                      Drama
# 348                Deadpool          2016  108 min  Action, Adventure, Comedy
# 349          Darbareye Elly          2009  119 min             Drama, Mystery
# 350                   Dev.D          2009  144 min             Drama, Romance
#
#      IMDB_Rating
# ...
