# %%
import pandas as pd

# %%
superstore_df = pd.read_csv("superstore.csv")
superstore_df.head()
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market               Order.Date        Order.ID Order.Priority  \
# 0       0.0     US  2011-01-07 00:00:00.000  CA-2011-130813           High
# 1       0.0     US  2011-01-21 00:00:00.000  CA-2011-148614         Medium
# 2       0.0     US  2011-08-05 00:00:00.000  CA-2011-118962         Medium
# 3       0.0     US  2011-08-05 00:00:00.000  CA-2011-118962         Medium
# 4       0.0     US  2011-09-29 00:00:00.000  CA-2011-146969           High
#
# ...

# %%
superstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer.ID     51290 non-null  object
#  4   Customer.Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   Order.Date      51290 non-null  object
#  8   Order.ID        51290 non-null  object
#  9   Order.Priority  51290 non-null  object
#  10  Product.ID      51290 non-null  object
#  11  Product.Name    51290 non-null  object
#  12  Profit          51290 non-null  float64
#  13  Quantity        51290 non-null  int64
#  14  Region          51290 non-null  object
#  15  Row.ID          51290 non-null  int64
#  16  Sales           51290 non-null  int64
# ...

# %%
# Membuat object untuk menyimpan hasil grouping
superstore_category = superstore_df.groupby('Category')
# Menampilkan minimal dari data hasil grouping
superstore_category.min()
# Out:
#                    City      Country Customer.ID  Customer.Name  Discount  \
# Category
# Furniture        Aachen  Afghanistan   AA-103151  Aaron Bergman       0.0
# Office Supplies  Aachen  Afghanistan   AA-103151  Aaron Bergman       0.0
# Technology       Aachen  Afghanistan   AA-103151  Aaron Bergman       0.0
#
#                 Market               Order.Date      Order.ID Order.Priority  \
# Category
# Furniture         APAC  2011-01-01 00:00:00.000  AE-2013-1130       Critical
# Office Supplies   APAC  2011-01-01 00:00:00.000  AE-2011-9160       Critical
# Technology        APAC  2011-01-02 00:00:00.000  AE-2011-9160       Critical
#
#                        Product.ID  ... Sales   Segment  \
# Category                           ...
# Furniture        FUR-ADV-10000002  ...     2  Consumer
# Office Supplies  OFF-ACC-10000102  ...     0  Consumer
# Technology        TEC-AC-10000007  ...     1  Consumer
#
# ...

# %%
superstore_category.max()
# Out:
#                                   City   Country Customer.ID  \
# Category
# Furniture                       Zurich  Zimbabwe   ZD-219254
# Office Supplies  Águas Lindas de Goiás  Zimbabwe   ZD-219254
# Technology                      Zurich  Zimbabwe   ZD-219254
#
#                       Customer.Name  Discount Market               Order.Date  \
# Category
# Furniture        Zuschuss Donatelli      0.85     US  2014-12-31 00:00:00.000
# Office Supplies  Zuschuss Donatelli      0.80     US  2014-12-31 00:00:00.000
# Technology       Zuschuss Donatelli      0.70     US  2014-12-31 00:00:00.000
#
#                      Order.ID Order.Priority        Product.ID  ...  Sales  \
# Category                                                        ...
# Furniture        ZI-2014-6030         Medium  FUR-TEN-10004549  ...   5760
# Office Supplies  ZI-2014-9650         Medium  OFF-XER-10004820  ...   9893
# Technology       ZI-2014-9550         Medium  TEC-STA-10004927  ...  22638
#
# ...

# %%
# Menampilkan maksimal dari data hasil grouping
superstore_category.max()
# Out:
#                                   City   Country Customer.ID  \
# Category
# Furniture                       Zurich  Zimbabwe   ZD-219254
# Office Supplies  Águas Lindas de Goiás  Zimbabwe   ZD-219254
# Technology                      Zurich  Zimbabwe   ZD-219254
#
#                       Customer.Name  Discount Market               Order.Date  \
# Category
# Furniture        Zuschuss Donatelli      0.85     US  2014-12-31 00:00:00.000
# Office Supplies  Zuschuss Donatelli      0.80     US  2014-12-31 00:00:00.000
# Technology       Zuschuss Donatelli      0.70     US  2014-12-31 00:00:00.000
#
#                      Order.ID Order.Priority        Product.ID  ...  Sales  \
# Category                                                        ...
# Furniture        ZI-2014-6030         Medium  FUR-TEN-10004549  ...   5760
# Office Supplies  ZI-2014-9650         Medium  OFF-XER-10004820  ...   9893
# Technology       ZI-2014-9550         Medium  TEC-STA-10004927  ...  22638
#
# ...
